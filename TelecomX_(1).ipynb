# %% [markdown]
# #IMPORTAÇÃO DE BIBLIOTECAS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10,6)

# %% [markdown]
# #IMPORTANDO OS DADOS

# %%
dados_telecom = pd.read_json('/content/TelecomX_Data (1).json')
dados_telecom
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %% [markdown]
# #DICIONÁRIO DOS DADOS

# %%
df = pd.json_normalize(dados_telecom.to_dict(orient='records'))
df
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# 1                  No                  No                9                Yes
# 2                  No                  No                4                Yes
# 3                 Yes                  No               13                Yes
# 4                 Yes                  No                3                Yes
# ...               ...                 ...              ...                ...
# 7262               No                  No               13                Yes
# 7263              Yes                  No               22                Yes
# 7264               No                  No                2                Yes
# 7265              Yes                 Yes               67                Yes
# 7266              Yes                 Yes               63                 No
#
#      phone.MultipleLines internet.InternetService  ... internet.OnlineBackup  \
# 0                     No                      DSL  ...                   Yes
# 1                    Yes                      DSL  ...                    No
# 2                     No              Fiber optic  ...                    No
# 3                     No              Fiber optic  ...                   Yes
# 4                     No              Fiber optic  ...                    No
# ...                  ...                      ...  ...                   ...
# 7262                  No                      DSL  ...                    No
# 7263                 Yes              Fiber optic  ...                    No
# 7264                  No                      DSL  ...                   Yes
# 7265                  No                      DSL  ...                    No
# 7266    No phone service                      DSL  ...                   Yes
#
#      internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# 0                           No                  Yes                  Yes
# 1                           No                   No                   No
# 2                          Yes                   No                   No
# 3                          Yes                   No                  Yes
# 4                           No                  Yes                  Yes
# ...                        ...                  ...                  ...
# 7262                        No                  Yes                   No
# 7263                        No                   No                   No
# 7264                        No                   No                   No
# 7265                       Yes                  Yes                   No
# 7266                       Yes                   No                  Yes
#
#      internet.StreamingMovies account.Contract account.PaperlessBilling  \
# 0                          No         One year                      Yes
# 1                         Yes   Month-to-month                       No
# 2                          No   Month-to-month                      Yes
# 3                         Yes   Month-to-month                      Yes
# 4                          No   Month-to-month                      Yes
# ...                       ...              ...                      ...
# 7262                       No         One year                       No
# 7263                      Yes   Month-to-month                      Yes
# 7264                       No   Month-to-month                      Yes
# 7265                      Yes         Two year                       No
# 7266                      Yes         Two year                       No
#
#      account.PaymentMethod account.Charges.Monthly  account.Charges.Total
# 0             Mailed check                   65.60                  593.3
# 1             Mailed check                   59.90                  542.4
# 2         Electronic check                   73.90                 280.85
# 3         Electronic check                   98.00                1237.85
# 4             Mailed check                   83.90                  267.4
# ...                    ...                     ...                    ...
# 7262          Mailed check                   55.15                  742.9
# 7263      Electronic check                   85.10                 1873.7
# 7264          Mailed check                   50.30                  92.75
# 7265          Mailed check                   67.85                4627.65
# 7266      Electronic check                   59.00                 3707.6
#
# [7267 rows x 21 columns]

# %% [markdown]
# * `customerID`: número de identificação único de cada cliente
# * `Churn`: se o cliente deixou ou não a empresa
# * `gender`: gênero (masculino e feminino)
# * `SeniorCitizen`: informação sobre um cliente ter ou não idade igual ou maior que 65 anos
# * `Partner`:  se o cliente possui ou não um parceiro ou parceira
# * `Dependents`: se o cliente possui ou não dependentes
# * `tenure`:  meses de contrato do cliente
# * `PhoneService`: assinatura de serviço telefônico
# * `MultipleLines`: assisnatura de mais de uma linha de telefone
# * `InternetService`: assinatura de um provedor internet
# * `OnlineSecurity`: assinatura adicional de segurança online
# * `OnlineBackup`: assinatura adicional de backup online
# * `DeviceProtection`: assinatura adicional de proteção no dispositivo
# * `TechSupport`: assinatura adicional de suporte técnico, menos tempo de espera
# * `StreamingTV`: assinatura de TV a cabo
# * `StreamingMovies`: assinatura de streaming de filmes
# * `Contract`: tipo de contrato
# * `PaperlessBilling`: se o cliente prefere receber online a fatura
# * `PaymentMethod`: forma de pagamento
# * `Charges.Monthly`: total de todos os serviços do cliente por mês
# * `Charges.Total`: total gasto pelo cliente

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
#  13  internet.TechSupport       7267 non-null   object
#  14  internet.StreamingTV       7267 non-null   object
#  15  internet.StreamingMovies   7267 non-null   object
#  16  account.Contract           7267 non-null   object
#  17  account.PaperlessBilling   7267 non-null   object
#  18  account.PaymentMethod      7267 non-null   object
#  19  account.Charges.Monthly    7267 non-null   float64
#  20  account.Charges.Total      7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %% [markdown]
# #VERIFICAÇÕES

# %% [markdown]
# 1. VERIFICAÇÃO DE VALORES UNICOS

# %%
for col in df.columns:
    print(f'{col}): {df[col].unique()}')

    if df[col].nunique() < 50:
        print(df[col].unique())

    print('-'*50)
# Out:
# customerID): ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# --------------------------------------------------
# Churn): ['No' 'Yes' '']
# ['No' 'Yes' '']
# --------------------------------------------------
# customer.gender): ['Female' 'Male']
# ['Female' 'Male']
# --------------------------------------------------
# customer.SeniorCitizen): [0 1]
# [0 1]
# --------------------------------------------------
# customer.Partner): ['Yes' 'No']
# ['Yes' 'No']
# --------------------------------------------------
# customer.Dependents): ['Yes' 'No']
# ['Yes' 'No']
# --------------------------------------------------
# customer.tenure): [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
# --------------------------------------------------
# phone.PhoneService): ['Yes' 'No']
# ['Yes' 'No']
# --------------------------------------------------
# phone.MultipleLines): ['No' 'Yes' 'No phone service']
# ['No' 'Yes' 'No phone service']
# --------------------------------------------------
# internet.InternetService): ['DSL' 'Fiber optic' 'No']
# ['DSL' 'Fiber optic' 'No']
# --------------------------------------------------
# internet.OnlineSecurity): ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# --------------------------------------------------
# internet.OnlineBackup): ['Yes' 'No' 'No internet service']
# ['Yes' 'No' 'No internet service']
# --------------------------------------------------
# internet.DeviceProtection): ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# --------------------------------------------------
# internet.TechSupport): ['Yes' 'No' 'No internet service']
# ['Yes' 'No' 'No internet service']
# --------------------------------------------------
# internet.StreamingTV): ['Yes' 'No' 'No internet service']
# ['Yes' 'No' 'No internet service']
# --------------------------------------------------
# internet.StreamingMovies): ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# --------------------------------------------------
# account.Contract): ['One year' 'Month-to-month' 'Two year']
# ['One year' 'Month-to-month' 'Two year']
# --------------------------------------------------
# account.PaperlessBilling): ['Yes' 'No']
# ['Yes' 'No']
# --------------------------------------------------
# account.PaymentMethod): ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
# ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
# --------------------------------------------------
# account.Charges.Monthly): [65.6  59.9  73.9  ... 91.75 68.8  67.85]
# --------------------------------------------------
# account.Charges.Total): ['593.3' '542.4' '280.85' ... '742.9' '4627.65' '3707.6']
# --------------------------------------------------

# %% [markdown]
# 2. VERIFICAÇÃO DE VALORES DUPLICADOS

# %%
print("Numero de duplicados", df.duplicated().sum())
# Out:
# Numero de duplicados 0

# %% [markdown]
# 3. VERIFICAÇÃO DE VALORES NULOS

# %%
print("Numero de nulos \n", df.isnull().sum())
# Out:
# Numero de nulos
#  customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %% [markdown]
# 4. VERIFICAÇÃO DE VALORES VAZIOS OU EM BRANCO

# %%
df.apply(lambda x: x.astype(str).str.strip() == '').sum()
# Out:
# customerID                     0
# Churn                        224
# customer.gender                0
# customer.SeniorCitizen         0
# customer.Partner               0
# customer.Dependents            0
# customer.tenure                0
# phone.PhoneService             0
# phone.MultipleLines            0
# internet.InternetService       0
# internet.OnlineSecurity        0
# internet.OnlineBackup          0
# internet.DeviceProtection      0
# internet.TechSupport           0
# internet.StreamingTV           0
# internet.StreamingMovies       0
# account.Contract               0
# account.PaperlessBilling       0
# account.PaymentMethod          0
# account.Charges.Monthly        0
# account.Charges.Total         11
# dtype: int64

# %% [markdown]
# # ORGANIZANDO INFORMAÇÕES ADCIONAIS

# %%
df['account.Charges.Total'] = pd.to_numeric(df['account.Charges.Total'], errors='coerce')

# %%
df= df[df['Churn'].str.strip() != '']

print("Número de filas depois de eliminar as vazias em 'Churn':", len(df))
# Out:
# Número de filas depois de eliminar as vazias em 'Churn': 7043

# %%
df.apply(lambda x: x.astype(str).str.strip() == '').sum()
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %%
print("Numero de nulos \n", df.isnull().sum())
# Out:
# Numero de nulos
#  customerID                    0
# Churn                         0
# customer.gender               0
# customer.SeniorCitizen        0
# customer.Partner              0
# customer.Dependents           0
# customer.tenure               0
# phone.PhoneService            0
# phone.MultipleLines           0
# internet.InternetService      0
# internet.OnlineSecurity       0
# internet.OnlineBackup         0
# internet.DeviceProtection     0
# internet.TechSupport          0
# internet.StreamingTV          0
# internet.StreamingMovies      0
# account.Contract              0
# account.PaperlessBilling      0
# account.PaymentMethod         0
# account.Charges.Monthly       0
# account.Charges.Total        11
# dtype: int64

# %%
df = df.dropna(subset=['account.Charges.Total'])

# %%
print("Numero de nulos \n", df.isnull().sum())
# Out:
# Numero de nulos
#  customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %% [markdown]
# # PADRONIZAÇÃO DE COLUNAS PARA PORTUGUÊS

# %%
import pandas as pd

dados_telecom = pd.read_json('/content/TelecomX_Data (1).json')
df = pd.json_normalize(dados_telecom.to_dict(orient='records'))

new_column_names = {
    'customerID': 'id_cliente',
    'Churn': 'evasao',
    'customer.gender': 'genero',
    'customer.SeniorCitizen': 'cidadao_senior',
    'customer.Partner': 'possui_parceiro',
    'customer.Dependents': 'possui_dependentes',
    'customer.tenure': 'meses_contrato',
    'phone.PhoneService': 'servico_telefone',
    'phone.MultipleLines': 'multiplas_linhas',
    'internet.InternetService': 'tipo_servico_internet',
    'internet.OnlineSecurity': 'seguranca_online',
    'internet.OnlineBackup': 'backup_online',
    'internet.DeviceProtection': 'protecao_dispositivo',
    'internet.TechSupport': 'suporte_tecnico',
    'internet.StreamingTV': 'streaming_tv',
    'internet.StreamingMovies': 'streaming_filmes',
    'account.Contract': 'tipo_contrato',
    'account.PaperlessBilling': 'fatura_online',
    'account.PaymentMethod': 'metodo_pagamento',
    'account.Charges.Monthly': 'cobranca_mensal',
    'account.Charges.Total': 'cobranca_total'
}

df = df.rename(columns=new_column_names)

yes_no_mapping = {'Yes': 'Sim', 'No': 'Não'}
for col in ['evasao', 'possui_parceiro', 'possui_dependentes', 'servico_telefone',
            'seguranca_online', 'backup_online', 'protecao_dispositivo',
            'suporte_tecnico', 'streaming_tv', 'streaming_filmes', 'fatura_online']:
    if col in df.columns:
        df[col] = df[col].replace(yes_no_mapping)

df['genero'] = df['genero'].replace({'Female': 'Feminino', 'Male': 'Masculino'})

df['multiplas_linhas'] = df['multiplas_linhas'].replace({'No phone service': 'Sem serviço de telefone', 'Yes': 'Sim', 'No': 'Não'})
df['tipo_servico_internet'] = df['tipo_servico_internet'].replace({'No': 'Não', 'DSL': 'DSL', 'Fiber optic': 'Fibra óptica'})


for col in ['seguranca_online', 'backup_online', 'protecao_dispositivo',
            'suporte_tecnico', 'streaming_tv', 'streaming_filmes']:
    if col in df.columns:
        df[col] = df[col].replace({'No internet service': 'Sem serviço de internet'})

df['tipo_contrato'] = df['tipo_contrato'].replace({
    'Month-to-month': 'Mensal',
    'One year': 'Anual',
    'Two year': 'Dois anos'
})


df['metodo_pagamento'] = df['metodo_pagamento'].replace({
    'Mailed check': 'Cheque enviado',
    'Electronic check': 'Cheque eletrônico',
    'Credit card (automatic)': 'Cartão de crédito (automático)',
    'Bank transfer (automatic)': 'Transferência bancária (automática)'
})

df.head()
# Out:
#    id_cliente evasao     genero  cidadao_senior possui_parceiro  \
# 0  0002-ORFBO    Não   Feminino               0             Sim
# 1  0003-MKNFE    Não  Masculino               0             Não
# 2  0004-TLHLJ    Sim  Masculino               0             Não
# 3  0011-IGKFF    Sim  Masculino               1             Sim
# 4  0013-EXCHZ    Sim   Feminino               1             Sim
#
#   possui_dependentes  meses_contrato servico_telefone multiplas_linhas  \
# 0                Sim               9              Sim              Não
# 1                Não               9              Sim              Sim
# 2                Não               4              Sim              Não
# 3                Não              13              Sim              Não
# 4                Não               3              Sim              Não
#
#   tipo_servico_internet  ... backup_online protecao_dispositivo  \
# 0                   DSL  ...           Sim                  Não
# 1                   DSL  ...           Não                  Não
# 2          Fibra óptica  ...           Não                  Sim
# 3          Fibra óptica  ...           Sim                  Sim
# 4          Fibra óptica  ...           Não                  Não
#
#   suporte_tecnico streaming_tv streaming_filmes tipo_contrato fatura_online  \
# 0             Sim          Sim              Não         Anual           Sim
# 1             Não          Não              Sim        Mensal           Não
# 2             Não          Não              Não        Mensal           Sim
# 3             Não          Sim              Sim        Mensal           Sim
# 4             Sim          Sim              Não        Mensal           Sim
#
#     metodo_pagamento cobranca_mensal  cobranca_total
# 0     Cheque enviado            65.6           593.3
# 1     Cheque enviado            59.9           542.4
# 2  Cheque eletrônico            73.9          280.85
# 3  Cheque eletrônico            98.0         1237.85
# 4     Cheque enviado            83.9           267.4
#
# [5 rows x 21 columns]

# %% [markdown]
# # CARGA E ANÁLISE

# %%
df.describe()
# Out:
#        cidadao_senior  meses_contrato  cobranca_mensal  cobranca_total
# count     7032.000000     7032.000000      7032.000000     7032.000000
# mean         0.162400       32.421786        64.798208     2283.300441
# std          0.368844       24.545260        30.085974     2266.771362
# min          0.000000        1.000000        18.250000       18.800000
# 25%          0.000000        9.000000        35.587500      401.450000
# 50%          0.000000       29.000000        70.350000     1397.475000
# 75%          0.000000       55.000000        89.862500     3794.737500
# max          1.000000       72.000000       118.750000     8684.800000

# %%
df.describe(include='all')
# Out:
#         id_cliente evasao     genero  cidadao_senior possui_parceiro  \
# count         7032   7032       7032     7032.000000            7032
# unique        7032      2          2             NaN               2
# top     9995-HOTOH    Não  Masculino             NaN             Não
# freq             1   5163       3549             NaN            3639
# mean           NaN    NaN        NaN        0.162400             NaN
# std            NaN    NaN        NaN        0.368844             NaN
# min            NaN    NaN        NaN        0.000000             NaN
# 25%            NaN    NaN        NaN        0.000000             NaN
# 50%            NaN    NaN        NaN        0.000000             NaN
# 75%            NaN    NaN        NaN        0.000000             NaN
# max            NaN    NaN        NaN        1.000000             NaN
#
#        possui_dependentes  meses_contrato servico_telefone multiplas_linhas  \
# count                7032     7032.000000             7032             7032
# unique                  2             NaN                2                3
# top                   Não             NaN              Sim              Não
# freq                 4933             NaN             6352             3385
# mean                  NaN       32.421786              NaN              NaN
# std                   NaN       24.545260              NaN              NaN
# min                   NaN        1.000000              NaN              NaN
# 25%                   NaN        9.000000              NaN              NaN
# 50%                   NaN       29.000000              NaN              NaN
# 75%                   NaN       55.000000              NaN              NaN
# max                   NaN       72.000000              NaN              NaN
#
#        tipo_servico_internet  ... backup_online protecao_dispositivo  \
# count                   7032  ...          7032                 7032
# unique                     3  ...             3                    3
# top             Fibra óptica  ...           Não                  Não
# freq                    3096  ...          3087                 3094
# mean                     NaN  ...           NaN                  NaN
# std                      NaN  ...           NaN                  NaN
# min                      NaN  ...           NaN                  NaN
# 25%                      NaN  ...           NaN                  NaN
# 50%                      NaN  ...           NaN                  NaN
# 75%                      NaN  ...           NaN                  NaN
# max                      NaN  ...           NaN                  NaN
#
#        suporte_tecnico streaming_tv streaming_filmes tipo_contrato  \
# count             7032         7032             7032          7032
# unique               3            3                3             3
# top                Não          Não              Não        Mensal
# freq              3472         2809             2781          3875
# mean               NaN          NaN              NaN           NaN
# std                NaN          NaN              NaN           NaN
# min                NaN          NaN              NaN           NaN
# 25%                NaN          NaN              NaN           NaN
# 50%                NaN          NaN              NaN           NaN
# 75%                NaN          NaN              NaN           NaN
# max                NaN          NaN              NaN           NaN
#
#        fatura_online   metodo_pagamento cobranca_mensal  cobranca_total
# count           7032               7032     7032.000000     7032.000000
# unique             2                  4             NaN             NaN
# top              Sim  Cheque eletrônico             NaN             NaN
# freq            4168               2365             NaN             NaN
# mean             NaN                NaN       64.798208     2283.300441
# std              NaN                NaN       30.085974     2266.771362
# min              NaN                NaN       18.250000       18.800000
# 25%              NaN                NaN       35.587500      401.450000
# 50%              NaN                NaN       70.350000     1397.475000
# 75%              NaN                NaN       89.862500     3794.737500
# max              NaN                NaN      118.750000     8684.800000
#
# [11 rows x 21 columns]

# %%
# MÉDIA
df.mean(numeric_only=True)
# Out:
# cidadao_senior        0.162400
# meses_contrato       32.421786
# cobranca_mensal      64.798208
# cobranca_total     2283.300441
# dtype: float64

# %%
# MEDIANA
df.median(numeric_only=True)
# Out:
# cidadao_senior        0.000
# meses_contrato       29.000
# cobranca_mensal      70.350
# cobranca_total     1397.475
# dtype: float64

# %%
# DESVIO PADRÃO
df.std(numeric_only=True)
# Out:
# cidadao_senior        0.368844
# meses_contrato       24.545260
# cobranca_mensal      30.085974
# cobranca_total     2266.771362
# dtype: float64

# %%
# ASSIMETRIA
df.skew(numeric_only=True)
# Out:
# cidadao_senior     1.831103
# meses_contrato     0.237731
# cobranca_mensal   -0.222103
# cobranca_total     0.961642
# dtype: float64

# %%
# CURTOSE
df.kurtosis(numeric_only=True)
# Out:
# cidadao_senior     1.353321
# meses_contrato    -1.387823
# cobranca_mensal   -1.256156
# cobranca_total    -0.231799
# dtype: float64

# %%
# COBRANÇA MENSAL POR CHURN
df.groupby("evasao")["cobranca_mensal"].describe()
# Out:
#          count       mean        std    min    25%    50%     75%     max
# evasao
# Não     5163.0  61.307408  31.094557  18.25  25.10  64.45  88.475  118.75
# Sim     1869.0  74.441332  24.666053  18.85  56.15  79.65  94.200  118.35

# %%
# COBRANÇA DIÁRIA POR CHURN
df['Contas_Diarias'] = df['cobranca_mensal'] / 30
df.groupby("evasao")["Contas_Diarias"].describe()
# Out:
#          count      mean       std       min       25%       50%       75%  \
# evasao
# Não     5163.0  2.043580  1.036485  0.608333  0.836667  2.148333  2.949167
# Sim     1869.0  2.481378  0.822202  0.628333  1.871667  2.655000  3.140000
#
#              max
# evasao
# Não     3.958333
# Sim     3.945000

# %%
# TENURE POR CHURN
df.groupby("evasao")["meses_contrato"].describe()
# Out:
#          count       mean        std  min   25%   50%   75%   max
# evasao
# Não     5163.0  37.650010  24.076940  1.0  15.0  38.0  61.0  72.0
# Sim     1869.0  17.979133  19.531123  1.0   2.0  10.0  29.0  72.0

# %%
# SERVIÇOS CONTRATADOS POR CHURN
cols_to_sum = [
    "seguranca_online",
    "backup_online",
    "servico_telefone"
]

for col in cols_to_sum:
    df[col] = df[col].map({'Sim': 1, 'Não': 0, 'Sem serviço de internet': 0})

df.groupby("evasao")[cols_to_sum].sum()
# Out:
#         seguranca_online  backup_online  servico_telefone
# evasao
# Não                 1720           1902              4653
# Sim                  295            523              1699

# %% [markdown]
# #CARREGAMENTO DOS DADOS

# %% [markdown]
# 1. ANÁLISE DESCRITIVA

# %%
df.describe()
# Out:
#        cidadao_senior  meses_contrato  servico_telefone  seguranca_online  \
# count     7032.000000     7032.000000       7032.000000       7032.000000
# mean         0.162400       32.421786          0.903299          0.286547
# std          0.368844       24.545260          0.295571          0.452180
# min          0.000000        1.000000          0.000000          0.000000
# 25%          0.000000        9.000000          1.000000          0.000000
# 50%          0.000000       29.000000          1.000000          0.000000
# 75%          0.000000       55.000000          1.000000          1.000000
# max          1.000000       72.000000          1.000000          1.000000
#
#        backup_online  cobranca_mensal  cobranca_total  Contas_Diarias
# count    7032.000000      7032.000000     7032.000000     7032.000000
# mean        0.344852        64.798208     2283.300441        2.159940
# std         0.475354        30.085974     2266.771362        1.002866
# min         0.000000        18.250000       18.800000        0.608333
# 25%         0.000000        35.587500      401.450000        1.186250
# 50%         0.000000        70.350000     1397.475000        2.345000
# 75%         1.000000        89.862500     3794.737500        2.995417
# max         1.000000       118.750000     8684.800000        3.958333

# %% [markdown]
# 2. DESCRIÇÃO DE EVASÃO

# %%
plt.figure(figsize=(12, 8))
churn_counts = df['evasao'].value_counts()
churn_percentages = churn_counts / len(df) * 100

ax = churn_counts.plot(kind='bar')
plt.title('Distribuição de Evasão de Clientes')
plt.xlabel('Cancelamento')
plt.ylabel('Quantidade de Clientes')
plt.xticks(rotation=0)

for i, percentage in enumerate(churn_percentages):
    ax.text(i, churn_counts.iloc[i] + 50, f'{percentage:.1f}%', ha='center' , va='bottom')

plt.show()

# %% [markdown]
# 3. CONTAGEM DE EVASÃO POR VARIAVEIS CATEGORICAS

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='genero', hue='evasao', palette='viridis')

plt.title('Contagem de Evasão por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Contagem de Clientes')
plt.xticks(rotation=0)

churn_by_gender = df.groupby('genero')['evasao'].value_counts().unstack(fill_value=0)

churn_percentage_by_gender = churn_by_gender.apply(lambda x: x / x.sum() * 100, axis=1)

for patch in ax.patches:
    height = patch.get_height()
    if height == 0:
        continue

    x_center = patch.get_x() + patch.get_width() / 2
    gender_index = int(round(x_center))
    if gender_index < len(ax.get_xticklabels()):
        gender_label = ax.get_xticklabels()[gender_index].get_text()
    else:
        continue

    churn_value = None
    for i, container in enumerate(ax.containers):
        if patch in container.patches:
            if i == 0:
                churn_str = 'Não'
            elif i == 1:
                churn_str = 'Sim'
            else:
                continue

            if churn_str in churn_percentage_by_gender.columns:
                percentage_val = churn_percentage_by_gender.loc[gender_label, churn_str]
                ax.annotate(f'{percentage_val:.1f}%', (x_center, height),
                            ha='center', va='bottom', fontsize=10, color='black')
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# 4. CONTAGEM DE EVASÃO POR SENIORIDADE

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='cidadao_senior', hue='evasao', palette='viridis')

plt.title('Contagem de Evasão por Senioridade (+60)')
plt.xlabel('Senior Citizen (0: Não, 1: Sim)')
plt.ylabel('Contagem de Clientes')
plt.xticks(ticks=[0, 1], labels=['Não Sênior', 'Sênior'], rotation=0)

churn_by_seniority = df.groupby('cidadao_senior')['evasao'].value_counts().unstack(fill_value=0)

churn_percentage_by_seniority = churn_by_seniority.apply(lambda x: x / x.sum() * 100, axis=1)

for patch in ax.patches:
    height = patch.get_height()
    if height == 0:
        continue

    x_center = patch.get_x() + patch.get_width() / 2
    seniority_index = int(round(x_center))

    churn_str = None
    for i, container in enumerate(ax.containers):
        if patch in container.patches:
            if i == 0:
                churn_str = 'Não'
            elif i == 1:
                churn_str = 'Sim'
            break

    if churn_str is not None and seniority_index in churn_percentage_by_seniority.index:
        if churn_str in churn_percentage_by_seniority.columns:
            percentage_val = churn_percentage_by_seniority.loc[seniority_index, churn_str]
            ax.annotate(f'{percentage_val:.1f}%', (x_center, height),
                        ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# 5. CONTAGEM DE EVASÃO POR TIPO DE CONTRATO

# %%
plt.figure(figsize=(12, 7))
ax = sns.countplot(data=df, x='tipo_contrato', hue='evasao', palette='viridis')

plt.title('Contagem de Evasão por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Contagem de Clientes')
plt.xticks(rotation=45, ha='right')

contract_churn_counts = df.groupby('tipo_contrato')['evasao'].value_counts().unstack(fill_value=0)
contract_percentage_by_churn = contract_churn_counts.apply(lambda x: x / x.sum() * 100, axis=1)

for patch in ax.patches:
    height = patch.get_height()
    if height == 0:
        continue

    x_center = patch.get_x() + patch.get_width() / 2
    contract_index = int(round(x_center))
    contract_label = ax.get_xticklabels()[contract_index].get_text()

    churn_str = None
    for i, container in enumerate(ax.containers):
        if patch in container.patches:
            if i == 0:
                churn_str = 'Não'
            elif i == 1:
                churn_str = 'Sim'
            break

    if churn_str is not None and contract_label in contract_percentage_by_churn.index:
        if churn_str in contract_percentage_by_churn.columns:
            percentage_val = contract_percentage_by_churn.loc[contract_label, churn_str]
            ax.annotate(f'{percentage_val:.1f}%', (x_center, height),
                        ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# 6. CONTAGEM DE EVASÃO POR FORMA DE PAGAMENTO

# %%
plt.figure(figsize=(12, 7))
ax = sns.countplot(data=df, x='metodo_pagamento', hue='evasao', palette='viridis')

plt.title('Contagem de Evasão por Forma de Pagamento')
plt.xlabel('Forma de Pagamento')
plt.ylabel('Contagem de Clientes')
plt.xticks(rotation=45, ha='right')

payment_method_churn_counts = df.groupby('metodo_pagamento')['evasao'].value_counts().unstack(fill_value=0)
payment_method_percentage_by_churn = payment_method_churn_counts.apply(lambda x: x / x.sum() * 100, axis=1)

for patch in ax.patches:
    height = patch.get_height()
    if height == 0:
        continue

    x_center = patch.get_x() + patch.get_width() / 2
    payment_method_index = int(round(x_center))
    payment_method_label = ax.get_xticklabels()[payment_method_index].get_text()

    churn_str = None
    for i, container in enumerate(ax.containers):
        if patch in container.patches:
            if i == 0:
                churn_str = 'Não'
            elif i == 1:
                churn_str = 'Sim'
            break

    if churn_str is not None and payment_method_label in payment_method_percentage_by_churn.index:
        if churn_str in payment_method_percentage_by_churn.columns:
            percentage_val = payment_method_percentage_by_churn.loc[payment_method_label, churn_str]
            ax.annotate(f'{percentage_val:.1f}%', (x_center, height),
                        ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# 7. CONTAGEM DE EVASÃO POR TIPO DE SERVIÇO DE INTERNET

# %%
plt.figure(figsize=(12, 7))
ax = sns.countplot(data=df, x='tipo_servico_internet', hue='evasao', palette='viridis')

plt.title('Contagem de Evasão por Tipo de Serviço de Internet')
plt.xlabel('Tipo de Serviço de Internet')
plt.ylabel('Contagem de Clientes')
plt.xticks(rotation=45, ha='right')

internet_churn_counts = df.groupby('tipo_servico_internet')['evasao'].value_counts().unstack(fill_value=0)
internet_percentage_by_churn = internet_churn_counts.apply(lambda x: x / x.sum() * 100, axis=1)

for patch in ax.patches:
    height = patch.get_height()
    if height == 0:
        continue

    x_center = patch.get_x() + patch.get_width() / 2
    internet_index = int(round(x_center))
    internet_label = ax.get_xticklabels()[internet_index].get_text()

    churn_str = None
    for i, container in enumerate(ax.containers):
        if patch in container.patches:
            if i == 0:
                churn_str = 'Não'
            elif i == 1:
                churn_str = 'Sim'
            break

    if churn_str is not None and internet_label in internet_percentage_by_churn.index:
        if churn_str in internet_percentage_by_churn.columns:
            percentage_val = internet_percentage_by_churn.loc[internet_label, churn_str]
            ax.annotate(f'{percentage_val:.1f}%', (x_center, height),
                        ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# 8. CONTAGEM DE EVASÃO POR POSSUIR PARCEIRO

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='possui_parceiro', hue='evasao', palette='viridis')

plt.title('Contagem de Evasão por Posse de Parceiro')
plt.xlabel('Possui Parceiro')
plt.ylabel('Contagem de Clientes')
plt.xticks(ticks=[0, 1], labels=['Não', 'Sim'], rotation=0)

churn_by_partner = df.groupby('possui_parceiro')['evasao'].value_counts().unstack(fill_value=0)
churn_percentage_by_partner = churn_by_partner.apply(lambda x: x / x.sum() * 100, axis=1)

for patch in ax.patches:
    height = patch.get_height()
    if height == 0:
        continue

    x_center = patch.get_x() + patch.get_width() / 2
    partner_label = ax.get_xticklabels()[int(round(x_center))].get_text()

    churn_str = None
    for i, container in enumerate(ax.containers):
        if patch in container.patches:
            if i == 0:
                churn_str = 'Não'
            elif i == 1:
                churn_str = 'Sim'
            break

    if churn_str is not None and partner_label in churn_percentage_by_partner.index:
        if churn_str in churn_percentage_by_partner.columns:
            percentage_val = churn_percentage_by_partner.loc[partner_label, churn_str]
            ax.annotate(f'{percentage_val:.1f}%', (x_center, height),
                        ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# 9. CONTAGEM DE EVASÃO POR POSSUIR DEPENDENTES

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 7))

viridis_palette = sns.color_palette('viridis', n_colors=2)

g = sns.catplot(data=df, x='possui_dependentes', hue='evasao', col='genero', kind='count', palette=viridis_palette, height=5, aspect=1.2)
g.set_axis_labels('Possui Dependentes', 'Contagem de Clientes')
g.set_titles('Evasão por Posse de Dependentes e Gênero: {col_name}')

churn_by_dependents_gender = df.groupby(['genero', 'possui_dependentes'])['evasao'].value_counts().unstack(fill_value=0)

for ax in g.axes.flat:
    for p in ax.patches:
        height = p.get_height()
        if height == 0:
            continue

        gender_label = ax.get_title().split(': ')[1]

        x_coord = p.get_x() + p.get_width() / 2
        dependents_label_str = ax.get_xticklabels()[int(round(x_coord))].get_text()

        if p.get_facecolor() == viridis_palette[0]:
            churn_str = 'Não'
        else:
            churn_str = 'Sim'

        if dependents_label_str in churn_by_dependents_gender.loc[gender_label].index and churn_str in churn_by_dependents_gender.loc[gender_label].columns:
            total_for_category = churn_by_dependents_gender.loc[(gender_label, dependents_label_str)].sum()
            percentage = (churn_by_dependents_gender.loc[(gender_label, dependents_label_str), churn_str] / total_for_category) * 100
            ax.annotate(f'{percentage:.1f}%',
                        (p.get_x() + p.get_width() / 2., height),
                        ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# 10. CONTAGEM DE EVASÃO POR SUPORTE TÉCNICO

# %%
plt.figure(figsize=(14, 7))

viridis_palette = sns.color_palette('viridis', n_colors=2)

g = sns.catplot(data=df, x='suporte_tecnico', hue='evasao', col='genero', kind='count', palette=viridis_palette, height=5, aspect=1.2)
g.set_axis_labels('Suporte Técnico', 'Contagem de Clientes')
g.set_titles('Evasão por Suporte Técnico : {col_name}')

churn_by_tech_support_gender = df.groupby(['genero', 'suporte_tecnico'])['evasao'].value_counts().unstack(fill_value=0)

for ax in g.axes.flat:
    for p in ax.patches:
        height = p.get_height()
        if height == 0:
            continue

        gender_label = ax.get_title().split(': ')[1]

        x_coord = p.get_x() + p.get_width() / 2
        tech_support_label_str = ax.get_xticklabels()[int(round(x_coord))].get_text()

        if p.get_facecolor() == viridis_palette[0]:
            churn_str = 'Não'
        else:
            churn_str = 'Sim'

        if tech_support_label_str in churn_by_tech_support_gender.loc[gender_label].index and churn_str in churn_by_tech_support_gender.loc[gender_label].columns:
            total_for_category = churn_by_tech_support_gender.loc[(gender_label, tech_support_label_str)].sum()
            percentage = (churn_by_tech_support_gender.loc[(gender_label, tech_support_label_str), churn_str] / total_for_category) * 100
            ax.annotate(f'{percentage:.1f}%',
                        (p.get_x() + p.get_width() / 2., height),
                        ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# 11. CONTAGEM DE EVASÃO POR MULTIPLAS LINHAS

# %%
plt.figure(figsize=(14, 7))

viridis_palette = sns.color_palette('viridis', n_colors=2)

g = sns.catplot(data=df, x='multiplas_linhas', hue='evasao', col='genero', kind='count', palette=viridis_palette, height=5, aspect=1.2)
g.set_axis_labels('Múltiplas Linhas', 'Contagem de Clientes')
g.set_titles('Evasão por Múltiplas Linhas : {col_name}')

churn_by_multiple_lines_gender = df.groupby(['genero', 'multiplas_linhas'])['evasao'].value_counts().unstack(fill_value=0)

for ax in g.axes.flat:
    for p in ax.patches:
        height = p.get_height()
        if height == 0:
            continue

        gender_label = ax.get_title().split(': ')[1]

        x_coord = p.get_x() + p.get_width() / 2
        multiple_lines_label_str = ax.get_xticklabels()[int(round(x_coord))].get_text()

        if p.get_facecolor() == viridis_palette[0]:
            churn_str = 'Não'
        else:
            churn_str = 'Sim'

        if multiple_lines_label_str in churn_by_multiple_lines_gender.loc[gender_label].index and churn_str in churn_by_multiple_lines_gender.loc[gender_label].columns:
            total_for_category = churn_by_multiple_lines_gender.loc[(gender_label, multiple_lines_label_str)].sum()
            percentage = (churn_by_multiple_lines_gender.loc[(gender_label, multiple_lines_label_str), churn_str] / total_for_category) * 100
            ax.annotate(f'{percentage:.1f}%',
                        (p.get_x() + p.get_width() / 2., height),
                        ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# 12. CONTAGEM DE EVASÃO POR TIPO DE SERVIÇO DE INTERNET

# %%
plt.figure(figsize=(14, 7))

viridis_palette = sns.color_palette('viridis', n_colors=2)

g = sns.catplot(data=df, x='tipo_servico_internet', hue='evasao', col='genero', kind='count', palette=viridis_palette, height=5, aspect=1.2)
g.set_axis_labels('Tipo de Serviço de Internet', 'Contagem de Clientes')
g.set_titles('Evasão por Tipo de Serviço de Internet : {col_name}')

churn_by_internet_service_gender = df.groupby(['genero', 'tipo_servico_internet'])['evasao'].value_counts().unstack(fill_value=0)

for ax in g.axes.flat:
    for p in ax.patches:
        height = p.get_height()
        if height == 0:
            continue

        gender_label = ax.get_title().split(': ')[1]

        x_coord = p.get_x() + p.get_width() / 2
        internet_service_label_str = ax.get_xticklabels()[int(round(x_coord))].get_text()

        if p.get_facecolor() == viridis_palette[0]:
            churn_str = 'Não'
        else:
            churn_str = 'Sim'

        if internet_service_label_str in churn_by_internet_service_gender.loc[gender_label].index and churn_str in churn_by_internet_service_gender.loc[gender_label].columns:
            total_for_category = churn_by_internet_service_gender.loc[(gender_label, internet_service_label_str)].sum()
            percentage = (churn_by_internet_service_gender.loc[(gender_label, internet_service_label_str), churn_str] / total_for_category) * 100
            ax.annotate(f'{percentage:.1f}%',
                        (p.get_x() + p.get_width() / 2., height),
                        ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# # HISTORIOGRAMAS NÃO INTERATIVOS

# %%
import plotly.express as px

# %%
plt.figure(figsize=(15, 8))
sns.histplot(data=df, x='meses_contrato', hue='evasao', multiple='dodge', shrink=0.8, palette={'Não': 'red', 'Sim': 'blue'})
plt.title('Distribuição de Evasão por Meses de Contrato')
plt.xlabel('Meses de Contrato')
plt.ylabel('Contagem de Clientes')
plt.tight_layout()
plt.show()

# %% [markdown]
# CONTAGEM DE EVASÃO POR FORMA DE PAGAMENTO

# %%
plt.figure(figsize=(15, 8))
ax = sns.countplot(data=df, x='metodo_pagamento', hue='evasao', palette={'Não': 'red', 'Sim': 'blue'})

plt.title('Contagem de Evasão por Forma de Pagamento')
plt.xlabel('Forma de Pagamento')
plt.ylabel('Contagem de Clientes')
plt.xticks(rotation=45, ha='right')

payment_method_churn_counts = df.groupby('metodo_pagamento')['evasao'].value_counts().unstack(fill_value=0)
payment_method_percentage_by_churn = payment_method_churn_counts.apply(lambda x: x / x.sum() * 100, axis=1)

for patch in ax.patches:
    height = patch.get_height()
    if height == 0:
        continue

    x_center = patch.get_x() + patch.get_width() / 2
    payment_method_index = int(round(x_center))
    payment_method_label = ax.get_xticklabels()[payment_method_index].get_text()

    churn_str = None
    for i, container in enumerate(ax.containers):
        if patch in container.patches:
            if i == 0:
                churn_str = 'Não'
            elif i == 1:
                churn_str = 'Sim'
            break

    if churn_str is not None and payment_method_label in payment_method_percentage_by_churn.index:
        if churn_str in payment_method_percentage_by_churn.columns:
            percentage_val = payment_method_percentage_by_churn.loc[payment_method_label, churn_str]
            ax.annotate(f'{percentage_val:.1f}%', (x_center, height),
                        ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# #RELATÓRIO FINAL

# %% [markdown]
# # 📈 Análise de Evasão de Clientes (Churn) — TelecomX
#
# ## 1. Objetivo do Projeto
#
# Este projeto tem como finalidade investigar os fatores relacionados ao cancelamento de clientes na empresa TelecomX, buscando compreender quais características contratuais e financeiras influenciam a evasão.
#
# No setor de telecomunicações, a retenção de clientes é essencial para a sustentabilidade do negócio, pois afeta diretamente a receita, os custos de aquisição e a estabilidade da base de usuários.
#
# O trabalho foi desenvolvido nas seguintes etapas:
#
# - Coleta dos dados
# - Limpeza e organização
# - Análise exploratória
# - Interpretação dos resultados
#
# ---
#
# ## 2. Organização e Preparação dos Dados
#
# ### 2.1 Transformação da Variável Churn
#
# A variável que indica cancelamento foi convertida para formato numérico:
#
# - No = 0
# - Yes = 1
#
# Esse procedimento facilita a análise estatística e possibilita a criação futura de modelos preditivos.
#
# ---
#
# ### 2.2 Ajustes em Variáveis Categóricas
#
# Valores como:
#
# - "No internet service"
# - "No phone service"
#
# foram padronizados como "No", evitando inconsistências e simplificando a interpretação dos dados.
#
# ---
#
# ### 2.3 Conversão de Campos Numéricos
#
# As colunas:
#
# - `account_Charges.Monthly`
# - `account_Charges.Total`
#
# foram transformadas para o tipo numérico (`float`), tratando automaticamente valores inválidos.
#
# ---
#
# ### 2.4 Criação de Indicador Diário de Custo
#
# Foi criada a variável:
#
# **Gasto_Diario = Cobrança_Mensal / 30**
#
# Esse indicador permite avaliar o impacto do custo diário na decisão de cancelamento.
#
# ---
#
# ### 2.5 Verificação de Dados Ausentes
#
# Valores incorretos foram substituídos por `NaN` e analisados por meio de:
#
# - Frequência dos valores
# - Estatísticas descritivas
# - Avaliação da consistência das colunas
#
# ---
#
# ## 3. Exploração dos Dados (EDA)
#
# A análise foi conduzida considerando:
#
# - Distribuição geral do churn
# - Influência de variáveis categóricas
# - Relação com variáveis numéricas
#
# ---
#
# ### 3.1 Comportamento Geral do Churn
#
# Os dados mostram uma taxa relevante de cancelamento, característica comum em bases de empresas de telecomunicações, indicando a necessidade de estratégias voltadas à retenção.
#
# ---
#
# ### 3.2 Análise por Características Categóricas
#
# ####  Tipo de Contrato
#
# Clientes com contrato mensal apresentam maior índice de cancelamento, enquanto contratos anuais demonstram maior estabilidade.
#
# A ausência de fidelização aumenta a chance de saída do cliente.
#
# ---
#
# ####  Serviço de Internet
#
# Usuários do serviço de fibra óptica apresentam maior taxa de churn em comparação aos clientes de DSL.
#
# Isso pode estar associado ao valor mais elevado dos planos.
#
# ---
#
# ####  Serviços Complementares
#
# A falta de serviços como:
#
# - Segurança online
# - Suporte técnico
# - Proteção de dispositivos
#
# está relacionada a maiores taxas de evasão.
#
# Clientes que utilizam mais serviços tendem a permanecer por mais tempo.
#
# ---
#
# ####  Forma de Pagamento
#
# O pagamento via **Electronic Check** apresenta maior concentração de cancelamentos, sugerindo menor estabilidade no vínculo financeiro.
#
# ---
#
# ### 3.3 Análise de Variáveis Numéricas
#
# ####  Tempo de Contrato (Tenure)
#
# Clientes que cancelaram possuem tempo médio de permanência menor, indicando que o risco é maior nos primeiros meses.
#
# ---
#
# ####  Valor Mensal
#
# Usuários que cancelam possuem mensalidades médias superiores às dos clientes ativos, sugerindo sensibilidade ao preço.
#
# ---
#
# ####  Total Pago
#
# Clientes que cancelam apresentam menor valor acumulado, reforçando que a evasão ocorre principalmente no início do contrato.
#
# ---
#
# ####  Custo Diário
#
# O custo diário médio é levemente maior entre os clientes que cancelaram.
#
# ---
#
# ## 4. Principais Conclusões
#
# O cancelamento de clientes está associado principalmente a:
#
# - Contratos mensais
# - Baixo tempo de permanência
# - Valores mensais mais elevados
# - Ausência de serviços adicionais
# - Pagamento via Electronic Check
# - Uso de fibra óptica
#
# O risco está concentrado em clientes recentes e com menor vínculo com a empresa.
#
# ---
#
# ## 5. Impactos para o Negócio
#
# Os resultados indicam que o cancelamento não ocorre ao acaso, mas está ligado a fatores contratuais e financeiros.
#
# Os grupos mais vulneráveis são:
#
# - Clientes novos
# - Clientes com planos mais caros
# - Clientes sem contratos de fidelidade
#
# ---
#
# ## 6. Propostas de Ação
#
# Com base na análise, recomenda-se:
#
# - Criar um processo de acompanhamento para clientes nos primeiros 90 dias
# - Estimular a adesão a planos de maior duração
# - Oferecer pacotes com serviços adicionais
# - Reavaliar preços do serviço de fibra óptica
# - Incentivar métodos automáticos de pagamento
# - Desenvolver um modelo preditivo para identificar clientes com maior risco de cancelamento
#
# ---
#
# ## 7. Próximos Passos
#
# Como continuidade do estudo, sugere-se:
#
# - Construção de um modelo de classificação supervisionado
# - Avaliação por métricas como AUC, Recall e F1-score
# - Criação de um indicador de risco individual por cliente
